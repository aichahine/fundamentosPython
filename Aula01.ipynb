# %% [markdown]
# <a href="https://colab.research.google.com/github/aichahine/fundamentosPython/blob/main/Aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %% [markdown]
# 17/01/2026 Questões da primeira aula

# %%
''' 1.Variáveis Simples
Crie três variáveis e peça elas para o usuário:
. Uma chamada cidade que guarde o nome a sua cidade;
. Uma chamada ano que guarde o ano atual;
. Uma chamada temperatura que guarde um valor numérico representando a temperatura média da sua cidade;
Em seguida, imprima uma frase completa usando essas variáveis.
'''

cidade = input("Digite o nome da cidade: ")
print("O nome da sua cidade é:",cidade,"\n")

ano = int(input("Digite o ano atual: "))
print("O ano atual é:",ano,"\n")

temperatura = float(input("Digite a temperatura: "))
print("A temperatura média da sua cidade é:",temperatura,"\n")

print("A sua cidade é",cidade,", o ano atual é ",ano," e a temperatura média da sua cidade é ",temperatura,".\n")


''' 2.Operações matemáticas
Crie duas variáveis numéricas e peça elas para o usuário. Realize as seguintes operações matemáticas entre elas:
. Soma
. Subtração
. Multiplicação
. Divisão
Imprima os resultados de maneira clara e formatada.
'''

variavel1 = int(input("Digite um número inteiro: "))
variavel2 = int(input("Digite mais um número inteiro: "))
print("O valor da variável 1 é:",variavel1," e o valor da variável 2 é:",variavel2,"\n")

soma = variavel1+variavel2
print("A soma é:",soma,"\n")

subtracao = variavel1-variavel2
print("A subtração é:",subtracao,"\n")

multiplicacao = variavel1*variavel2
print("A multiplicação é:",multiplicacao,"\n")

divisao = variavel1/variavel2
print("A divisão é:",divisao,"\n")

print("Resultados:\nSoma:",soma,"\nSubtração:",subtracao,"\nMultiplicação:",multiplicacao,"\nDivisão:",divisao)
# Out:
# Digite o nome da cidade: São Paulo
# O nome da sua cidade é: São Paulo
#
# Digite o ano atual: 2026
# O ano atual é: 2026
#
# Digite a temperatura: 23.5
# A temperatura média da sua cidade é: 23.5
#
# A sua cidade é São Paulo , o ano atual é  2026  e a temperatura média da sua cidade é  23.5
#
# Digite um número inteiro: 4
# Digite mais um número inteiro: 5
# O valor da variável 1 é: 4  e o valor da variável 2 é: 5
#
# A soma é: 9
#
# A subtração é: -1
#
# A multiplicação é: 20
#
# A divisão é: 0.8
#
# Resultados:
# Soma: 9
# Subtração: -1
# Multiplicação: 20
# Divisão: 0.8
