# %%
'''07/03/2026 Sétima aula '''
''' Funções e Escopo '''

'''
Sintaxe da função
Argumentos (input) -> Função -> Valor do retorno (output)

def nomeDaFuncao(paramemetros)

Palavra-chave def
Nome da função
Parâmetro
Comando de retorno
Valor de retorno
'''

''' Definição da função '''
def fahrenheitToCelsius(temperatura):
  """
  Função que recebe como argumento uma temperatura
  em Fahrenheit e converte para Celsius
  """
  return ((temperatura-32)*(5/9))

''' Execução (invocação) da função '''
temperaturaCelsius = fahrenheitToCelsius(89)
print(f"{temperaturaCelsius:.2f}\n")

''' Invocando a função diretamente na impressão '''
print(fahrenheitToCelsius(92))

''' Retorna o valor do docstring '''
help(fahrenheitToCelsius)

def cumprimentar(nome):
  """
  Essa função irá imprimir um cumprimento com o nome passado por parâmetro
  """
  print(f"Olá, {nome}! Seja bem-vindo(a)!")

''' Invocando a função '''
cumprimentar("Aline")

''' Funções podem retornar um resultado ou imprimir um valor '''

''' Invocando uma função em um laço de repetição '''
''' Definição da função '''
def quadrado(numero):
  return numero*numero

tamanho = 6
numQuadrado = 0

''' Invocação da função '''
for i in range(tamanho):
  numQuadrado = quadrado(i)
  print(numQuadrado)

''' Exemplo '''

def soma(n1,n2):
  soma = n1+n2
  return soma

def subtracao(n1,n2):
  sub = n1-n2
  return sub

def multiplicacao(n1,n2):
  mult = n1*n2
  return mult

def divisao(n1,n2):
  if n2 == 0:
    print("Não é possível dividir um número por zero.")
  else:
    div = n1/n2
    return div

def potenciacao(n1,n2):
  pot = n1 ** n2
  return pot

def radiciacao(n1,n2):
  rad = n1 ** 0.5, n2 ** 0.5
  return rad


print("Bem-vindo à calculadora!\n")
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))
op = int(input("\nDigite:\n1 para somar\n2 para subtrair\n3 para multiplicar\n4 para dividir\n5 para potenciação\n6 para raiz quadrada\n"))
if op == 1:
  print(f"O valor da soma é: {num1} + {num2} = {soma(num1,num2)}")
elif op == 2:
  print(f"O valor da subtração é: {num1} - {num2} = {subtracao(num1,num2)}")
elif op == 3:
  print(f"O valor da multiplicação é: {num1} x {num2} = {multiplicacao(num1,num2)}")
elif op == 4:
  print(f"O valor da divisão é: {num1} / {num2} = {divisao(num1,num2)}")
elif op == 5:
  print(f"{num1} elevado a {num2} é = {potenciacao(num1,num2)}")
elif op == 6:
  print(f"A raiz quadrada de {num1} é = {radiciacao(num1,num2)}\n e a raiz quadrada de {num2} é = {radiciacao(num1,num2)}")
else:
  print("Operação inválida")


''' 1. Crie uma função chamada apresentação que receba um nome, idade e curso como parâmetro e imprima uma mensagem de
apresentação para a sala.
'''

def apresentacao(nome,idade,curso):
  print(f"Olá! Meu nome é {nome}, tenho {idade} anos de idade e frequento o curso de {curso}, muito prazer!")

nomeInput = input("Digite o nome: ")
idadeInput = int(input("Digite a idade: "))
cursoInput = input("Digite o curso: ")

apresentacao(nomeInput,idadeInput,cursoInput)


''' 2. Crie uma função chamada par_ou_impar que receba um número como parâmetro e
retorne "par" se ele for par e "ímpar" se for ímpar.
'''

def par_ou_impar(numero):
  if numero % 2 == 00:
    print(f"O número {numero} é par.")
  else:
    print(f"O número {numero} é ímpar.")

numero = int(input("Digite um número: "))

if numero !=0:
  par_ou_impar(numero)
else:
  print("Valor inválido!")


''' 3. Crie uma função que converta uma temperatura de Fahrenheit para Celsius e para
Kelvin e print os dois.
'''

def fToCelsius(temperatura):
  return ((temperatura-32)*(5/9))

def fToKelvin(temperatura):
  """
  Para converter Fahrenheit para Kelvin,
  deve-se converter inicialmente para Celsius
  """
  celsius = (temperatura-32)*(5/9)
  kelvin = celsius + 273.15
  return (kelvin)

tempF = float(input("Digite a temperatura em Fahrenheit: "))

fToCelsius(tempF)
print(f"Temperatura em Celsius: {fToCelsius(tempF):.2f}")

fToKelvin(tempF)
print(f"Temperatura em Kelvin: {fToKelvin(tempF):.2f}")


''' 4. Crie uma função eh_primo(n) que retorne True se n for primo e False caso contrário.
Use for. '''

def eh_primo(numero):
  """
  O número é primo quando:
  É divisível por si mesmo com resto zero e
  é divisível por um com resto zero
  """

# Número primo: divisível apenas por 1 ou por ele mesmo com resto 0
def eh_primo(n):
  if n > 1 and n != 2:
    for i in range(2, int(n**0.5)+1): # vai de dois até a raiz de 2 (potência de meio) mais um
      if n % i == 0:
        return False
        break
    else:
      return True
  else:
    print("É primo")

eh_primo(1)
eh_primo(2)
eh_primo(11)
eh_primo(6) # não é primo porque é divisível por 2
eh_primo(12) # não é primo porque é divisível por 2
# Out:
# É primo
# É primo
# False
