# %% [markdown]
# <a href="https://colab.research.google.com/github/aichahine/fundamentosPython/blob/main/Aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''24/01/2026 Segunda aula'''


'''Exemplo'''
media = float(input("Informe a média: "))

if media > 7:
  print("Aprovado")
elif media < 5:
  print("Reprovado")
else:
  print("Recuperação")


''' 1. Faça um programa que peça dois números ao usuário e mostre qual o maior e qual o menor ou se são iguais.'''
numero1 = float(input("Digite um número: "))
numero2 = float(input("Digite mais um número: "))

if numero1 > numero2:
  print("O primeiro número (",numero1,") é maior do que o segundo número (",numero2,")")
elif numero2 > numero1:
  print("O segundo número (",numero2,") é maior do que o primeiro número (",numero1,")")
else:
  print("Os números são iguais")


''' 2. Escreva um programa em Python que receba um inteiro e diga se é par ou ímpar ou se está zerado'''
numero = int(input("Digite um número inteiro: "))

'''if numero%2==0 and numero!=0:
  print("O número digitado é par (número digitado:",numero,").")
elif numero%2!=0 and numero!=0:
  print("O número digitado é ímpar (número digitado:",numero,").")
elif numero==0:
  print("O número digitado é zero.")'''

# Outra forma de execução
if numero==0:
  print("O número digitado é zero.")
elif numero%2==0:
  print("O número digitado é par (número digitado:",numero,").")
else:
    print("O número digitado é ímpar (número digitado:",numero,").")


''' 3. Faça um Programa que verifique o estado civil de uma pessoa. Se a letra digitada é
"C" (Casado), "S" (Solteiro), "D" (Divorciado), "V" (Viúvo) ou "O" (outros).
Conforme a letra escrita pelo usuário seu programa deve escrever o estado civil, exemplo:
Usuário digita: C
Seu programa deve responder:
C - Casado'''
#estadoCivil = input("Digite a letra correspondente ao seu estado civil:\nC (Casado)\nS (Solteiro)\nD (Divorciado)\nV (Viúvo)\nO (Outros)\n")
estadoCivil = input("Digite a letra inicial do seu estado civil: ").upper()

if estadoCivil == "C":
  print("O seu estado civil é: casado.")
elif estadoCivil == "S":
  print("O seu estado civil é: solteiro.")
elif estadoCivil == "D":
  print("O seu estado civil é: divorciado.")
elif estadoCivil == "V":
  print("O seu estado civil é: viúvo.")
elif estadoCivil == "O":
  print("O seu estado civil é: 'outros'.")
else:
  print("Não identifiquei o seu estado civil.")

''' 4. Calcule a obrigatoriedade do voto para uma pessoa dependendo de sua idade.
Voto é facultativo:
maiores de 16 anos e menores de 18 anos;
maiores ou igual a 70 anos. Demais idades o voto é obrigatório.'''
idade = int(input("Digite a idade do eleitor: "))

if (idade >=16 and idade <18) or idade>=70:
  print("O voto é facultativo.")
elif idade >=18 and idade <70:
  print("Demais idades: o voto é obrigatório.")
elif idade <16:
  print("Ainda não é eleitor.")
elif idade>120:
  print("Idade inválida.")

''' 5. Elabore um algoritmo que de acordo com a idade de um nadador classifique-o em uma das
seguintes categorias:
Infantil A = 5 a 7 anos (idade >= 5 and idade <= 7)
Infantil B = 8 a 11 anos
Juvenil A = 12 a 13 anos
Juvenil B = 14 a 17 anos
Adultos = Maiores de 18 anos'''

idade = int(input("Digite a sua idade: "))
if idade >=5 and idade <=7:
  print("A sua categoria é: 'Infantil A'")
elif idade >=8 and idade <=11:
  print("A sua categoria é: 'Infantil B'")
elif idade >=12 and idade <=13:
  print("A sua categoria é: 'Juvenil A'")
elif idade >=14 and idade <=17:
  print("A sua categoria é: 'Juvenil B'")
elif idade >18 and idade <=120:
  print("A sua categoria é: 'Adultos'")
elif idade <5:
  print("Menores de 5 anos ainda não são classificados.")
else:
  print("Idade inválida.")

''' 6. Faça um programa que solicite dois números ao usuário (decimais) Em seguida solicite
que o usuário informe a operação matemática (soma, subtração, multiplicação e divisão).
Imprima de forma formatada a operação selcionada.'''
numero1 = float(input("Digite um número decimal: "))
numero2 = float(input("Digite mais um número decimal: "))
operacao = input("Digite a operação matemática:\n+ Soma\n- Subtração\nx Multiplicação\n/ Divisão\n* Exponenciação\nr Radiciação\n")

if operacao == '+':
  print("\nA operação selecionada foi: soma\n",numero1,"+",numero2,"=",numero1+numero2)
elif operacao == '-':
  print("\nA operação selecionada foi: subtração\n",numero1,"-",numero2,"=",numero1-numero2)
elif operacao == 'x':
  print("\nA operação selecionada foi: multiplicação\n",numero1,"x",numero2,"=",numero1*numero2)
elif operacao == '/' and numero2!=0:
  print("\nA operação selecionada foi: divisão\n",numero1,"/",numero2,"=",numero1/numero2)
elif operacao == '*':
  print("\nA operação selecionada foi: exponenciação\n",numero1,"elevado a",numero2,"=",numero1**numero2)
elif operacao == 'r':
  print("\nA operação selecionada foi: radiciação\nA raiz de",numero1,"elevado a",numero2,"=",numero1**(1/numero2))
else:
  print("Operação inválida.")

''' Desafio – Desconto no posto de gasolina
Um posto está vendendo combustíveis com a seguinte tabela de descontos:

Álcool:
. até 20 litros, desconto de 3% no preço total;
. acima de 20 litros, desconto de 5% no preço total.

Gasolina:
até 20 litros, desconto de 4% no preço total;
acima de 20 litros, desconto de 6% no preço total.

Escreva um algoritmo que leia o número de litros vendidos e o
tipo de combustível (codificado da seguinte forma: A-álcool, G-gasolina), calcule e
imprima o valor a ser pago pelo cliente sabendo-se que o preço do litro da

gasolina é R$ 5,50 e o preço do litro do
álcool é R$ 3,89.'''

# tipoCombustivel = input("Digite o tipo de combustível:\nA - álcool\nG - gasolina\n").upper()
# volume = float(input("Digite o volume em litros de combustível que deseja abastecer: "))
# gasolina = 5.50
# alcool = 3.89

# # Álcool
# if tipoCombustivel == 'A' and volume<=20:
#   print("Valor sem desconto: ")
# elif alcool >20:
#   print("Desconto de 5%:",alcool*0.95)
# Out:
# Digite um número decimal: 2.0
# Digite mais um número decimal: 3.0
# Digite a operação matemática:
# + Soma
# - Subtração
# x Multiplicação
# / Divisão
# * Exponenciação
# r Radiciação
# *
#
# A operação selecionada foi: exponenciação
#  2.0 elevado a 3.0 = 8.0
