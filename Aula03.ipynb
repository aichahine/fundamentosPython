# %% [markdown]
# <a href="https://colab.research.google.com/github/aichahine/fundamentosPython/blob/main/Aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''31/01/2026 Terceira aula
Estruturas de controle de repetição '''


''' Exemplo: while com condição '''
x = 0
while x < 5:
  print("O valor de x é:",x)
  x = x + 1
else:
  print("Fim do código.")


''' Exemplo: while true '''
contador = 0
while True:
  print("O valor do contador é:",contador)
  contador += 1
  if contador >= 3:
    break


''' Exemplo '''
notas = 0
qtde_notas_info = 0

while True:
  nota = float(input("Informe a nota ou digite -1 para finalizar: "))
  if (nota == -1):
    break
  notas = notas + nota
  qtde_notas_info = qtde_notas_info + 1
  print(f"Quantidade de notas informadas: {qtde_notas_info}")

if qtde_notas_info > 0:
  media = notas / qtde_notas_info
  print("\nQuantidade de notas informadas:",qtde_notas_info)
  print(f"Média: {media:.2f}")
else:
  print("Nenhuma nota foi informada.")


''' Exercícios
1. Crie um programa que solicite ao usuário uma nota entre zero e dez. Se o
valor informado for inválido, exiba uma mensagem de erro e continue solicitando
uma nota válida até que o usuário a forneça.'''

nota = float(input("Digite uma nota entre zero e dez: "))

while nota < 0 or nota > 10:
  nota = float(input("Nova inválida. Digite uma nota entre zero e dez: "))
else:
  print(f"A nota digitada é: {nota:.2f}")


''' 2. Desenvolva um programa que calcule a média de alunos por turma. Para isso,
siga os passos abaixo:
. Solicite ao usuário a quantidade de turmas;
. Para cada turma, peça que o usuário informe a quantidade de alunos;
. Certifique-se de que o número de alunos por turma não ultrapasse 40;
. Ao final, exiba a média de alunos por turma. '''

# Recebendo o número de turmas
qtde_turmas = int(input("Digite a quantidade de turmas: "))

# Guardando o valor inicial de turmas informado, para ser utilizado para calcular a média
qtde_turmas_inicial = qtde_turmas

# Atributo para guardar o número total de alunos
total_alunos = 0

while qtde_turmas > 0:
  qtde_alunos = int(input(f"Digite a quantidade de alunos da turma: ")) # Recebendo o número de alunos
  total_alunos += qtde_alunos # Somando o número de alunos recebido
  qtde_turmas -= 1 # Subtraindo o número de turmas preenchido

  # Este trecho do código não está sendo somado ao total de alunos, corrigir:

  # while qtde_alunos > 40 or qtde_alunos <= 0: # Testando se o número de alunos recebido é válido
  #   qtde_alunos = int(input("Quantidade de alunos inválida.\nDigite a quantidade de alunos da turma: "))
  #   total_alunos += qtde_alunos

else:
  print(f"A média de alunos por turma é: {total_alunos/qtde_turmas_inicial:.2f}") # Exibindo a média


''' 3. Desenvolva um programa em Python que peça ao usuário para criar uma senha e,
em seguida, solicite que ele a digite novamente. Continue pedindo até que as duas
senhas correspondam. '''

senha1 = input("Digite sua senha: ")
senha2 = input("Digite sua senha novamente: ")

while senha1 != senha2:
  print("As senhas são diferentes.")
  senha1 = input("Digite sua senha: ")
  senha2 = input("Digite sua senha novamente: ")
else:
  print("As senhas são iguais.")

# Outra solução:

# senha1 = input("Digite sua senha: ")
# senha2 = input("Digite sua senha novamente: ")

# while senha1 != senha2:
#   senha2 = input("Digite sua senha novamente: ")
# else:
#   print("As senhas são iguais.")


''' 4. Crie um programa em Python que leia números inteiros do teclado até que o usuário
digite 0. Ao final, exiba a soma de todos os números digitados '''

# Atributo para somar os números recebidos
soma = 0

while True:
  numero = int(input("Digite um dos números do teclado ou zero para finalizar: "))
  soma += numero
  if numero == 0:
    print("\nPrograma encerrado.")
    break
  numero = int(input("Digite mais um número do teclado: "))
  soma += numero

print(f"Soma: {soma}")
# Out:
# Digite um dos números do teclado ou zero para finalizar: 2
# Digite mais um número do teclado: 5
# Digite um dos números do teclado ou zero para finalizar: 0
#
# Programa encerrado.
# Soma: 7
