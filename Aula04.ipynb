# %% [markdown]
# <a href="https://colab.research.google.com/github/aichahine/fundamentosPython/blob/main/Aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''07/02/2026 Quarta aula
Listas e estruturas de controle de repetição (for) '''

lista = [4,5,3,5]
print(f"Lista {lista}")

''' Adiciona um valor ao fim da lista '''
lista.append(2)
print(f"Append {lista}")

lista.insert(2,-3)
print(f"Insert {lista}")

lista.remove(4)
print(f"Remove {lista}")

lista.sort()
print(f"Sort {lista}")
lista.sort(desc)
print(f"Sort desc {lista}")


letra = ["a","b","c"]
print(f"Tamanho da lista: {len(letra)}")
print(f"Endereço da letra b: {letra.index("b")}")

letras = ["a","b","c","d","e","f","g","h","i","j","k","l"]
print(f"Nova lista: {letras}")
print(f"Tamanho da lista: {len(letras)}")
print(f"Endereço da letra a: {letras.index("a")}")


letras = ["a","b","c","d","e","f","g","h","i","j","k","l"]
var = input("Informe uma letra: ")
if var.lower() in letras:
  print(f"A letra '{var.lower()}' está na lista.")
else:
  print(f"A letra '{var.lower()}' não está na lista.")


letras.append("m")
print(f"A nova lista de letras é: {letras}")


nova = []
while True:
  num = int(input("Digite um número inteiro ou 0 para sair: "))
  if num == 0 or len(nova)==10:
    break
  nova.append(num)
print(f"A nova lista é: {nova}")


''' 1 - Faça um programa que leia do usuário 5 número inteiros e mostre-os. (Sem while True) '''
lista = []

while len(lista)<5:
  num = int(input("Digite um número: "))
  lista.append(num)
else:
  print(f"Os números digitados são: {lista}")


''' 2 - Faça um programa que leia do usuário 10 números reais e mostre-os na ordem inversa. (Sem While True) '''
lista = []

while len(lista)<10:
  num = float(input("Digite um número real: "))
  lista.append(num)
else:
  lista.reverse() # É necessário inverter a lista antes de exibir
  print(f"Os números digitados são: {lista}")


''' 3- Faça um Programa que leia 4 notas, mostre as notas e a média na tela. '''
lista = []
soma = 0

while len(lista)<4:
  nota = float(input("Digite uma nota: "))
  lista.append(nota)
  soma += nota
else:
  print(f"As notas são: {lista}.")
  print(f"A média é: {soma/len(lista):.2f}")


''' 4 - Faça um programa que leia um vetor de 10 caracteres, e diga quantas consoantes foram
lidas. Imprima as consoantes. '''
vetor = []
vogais = ["a", "e", "i", "o", "u"]
contador = 0

while len(vetor)<10:
  consoante = input("Digite uma letra: ")
  if consoante.lower() not in vogais:
    contador += 1
    vetor.append(consoante)
  else:
    print("Você digitou uma vogal.")
    print(f"As consoantes são: {vetor}.")
    print()


vetor_letras = []
vetor_consoantes = []

while len(vetor_letras):
  char = input("Digite uma letra: ")
  if char not in 'aeiou':
    contador_consoante += 1
    vetor_consoantes.append(char)
  vetor_letras.append(char)

  print(vetor_letras)
  print(f"O vetor possuis {contador_consoante} consoantes")
  print(vetor_consoantes)


''' 5 - Faça um programa que leia um vetor de 5 números inteiros, mostre a soma, a
multiplicação e os números. '''
vetor_num = []
soma = 0
mult = 1

while len(vetor_num)<5:
  num = int(input("Digite um número inteiro: "))
  vetor_num.append(num)
  soma += num
  mult *= num
else:
  print(f"Os números são: {vetor_num}.")
  print(f"A soma é: {soma}.")
  print(f"A multiplicação é: {mult}.")
# Out:
# Digite um número inteiro: 2
# Digite um número inteiro: 4
# Digite um número inteiro: 6
# Digite um número inteiro: 8
# Digite um número inteiro: 10
# Os números são: [2, 4, 6, 8, 10].
# A soma é: 30.
# A multiplicação é: 3840.
