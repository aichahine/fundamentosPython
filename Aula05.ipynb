# %% [markdown]
# <a href="https://colab.research.google.com/github/aichahine/fundamentosPython/blob/main/Aula05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''21/02/2026 Quinta aula
Tuplas e  dicionários '''


''' Exercícios - tuplas '''

''' 1. Crie uma tupla com 4 números inteiros e exiba o segundo número. '''

inteiros = 8, 6, 7, 5
print("O segundo número é:",inteiros[1])


''' 2. Crie duas tuplas com diferentes tipos de dados cada (ex: números e
strings). Imprima o index 2 da tupla de números e o index 3 da tupla de string
no mesmo print. '''

numeros = 9, 7, 8, 6
string = "nove", "sete", "oito", "seis"

print("\nO index 2 da tupla de números é:",numeros[2],"\ne o index 3 da tupla de string é:",string[3])


''' 3. Crie uma tupla numeros = (5, 10, 15, 20) e converta-a em uma lista.
Adicione o número 25 à lista resultante depois volte a lista para tupla e imprima. '''

''' Criando a tupla'''
numeros = (5, 10, 15, 20)

''' Convertendo a tupla em lista '''
lista_numeros = list(numeros)

''' Adicionando um valor à lista '''
lista_numeros.append(25)

''' Convertendo a lista em tupla '''
tupla = tuple(lista_numeros)

''' Imprimindo a tupla '''
print("\nA nova tupla é: ",lista_numeros)


''' Dicionários '''
dicionario = {
    "nome":"Ricardo",
    "idade": 37,
}

dic = {"curso": "python", "professor": "Ricardo"}
print(f"O curso de {dic["curso"]} é ministrado pelo professor {dic["professor"]}")


aluno = {
    "nome": "Renan",
    "idade": 24,
    "curso": "Python",
    "CPF": "123.456.789-10",
    "Endereço": "Rua Adolf",
}

print({aluno["idade"]})


''' Adicionando uma nova chave '''
aluno["Usa óculos?"] = True
print({aluno})


novoAluno = {
    "nome": "Aline",
    "idade": 39,
    "curso": "Fundamentos de Python I",
    "CPF": "354.828.208-31",
    "Endereço": "Rua William Speers, 248",
}

print("Meu nome é",{novoAluno["nome"]},"\nMinha idade é",{novoAluno["idade"]},"anos","\nEstou cursando",{novoAluno["curso"]},"\nO número do meu documento é",{novoAluno["CPF"]},"\ne moro na",{novoAluno["Endereço"]})
